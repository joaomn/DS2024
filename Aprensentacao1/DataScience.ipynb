# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# **Neste trabalho iremos explorar o dataset do governo de Minas Gerais do ano de 2021 com acidentes de trânsito com vítimas ocorridos em Belo Horizonte**

# %% [markdown]
# # Descrição dos passos seguidos nesta a tividade

# %%
# Passo 1: Instalar bibliotecas
# passo 2: Importar base de dados
# Passo 3: Leitura e vizualização da base de dados
# Passo 4: Corrigir erros da base de dados
# Passo 5: Análise dos dados
# Passo 6: Graficos Informativos

# %% [markdown]
# # Passo 1: Instalar bibliotecas

# %%
! pip install pandas numpy openpyxl nbformat ipykernel plotly seaborn
# Out:
# 'pip' n�o � reconhecido como um comando interno
# ou externo, um programa oper�vel ou um arquivo em lotes.

# %% [markdown]
# # Passo 2: Importar Bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import pandas as pd
#       2 import matplotlib.pyplot as plt
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# # Dicionario de Dados

# %%
dataset = pd.read_csv("dicionario-tabela-si-veic-2016.csv", sep=';', encoding='latin-1')

display(dataset)
# Out:
#          Nome_do_arquivo                                       si_veic-aaaa  \
# 0   Descricao_do_arquivo  Acidentes de transito com vitima dados gerais ...
# 1        Data_da_criacao                                             10/jan
# 2          Nome_do_campo                                    Layout_do_campo
# 3             Nº_boletim                                         NUMBER(18)
# 4      data_hora_boletim                                               DATE
# 5               seq_veic                                          NUMBER(2)
# 6              cod_categ                                          NUMBER(2)
# 7    descricao_categoria                                       VARCHAR2(30)
# 8            cod_especie                                          NUMBER(2)
# 9      descricao_especie                                       VARCHAR2(12)
# 10          cod_situacao                                          NUMBER(1)
# 11         desc_situacao                                       VARCHAR2(14)
# 12          tipo_socorro                                          NUMBER(1)
# 13     desc_tipo_socorro                                       VARCHAR2(18)
#
#                                            Unnamed: 2
# 0                                                 NaN
# 1                                                 NaN
# 2                                  descricao_do_campo
# 3   Numero do Boletim de Ocorrência. Exemplo: 2060...
# 4   Data e hora do acidente registrada no Boletim ...
# 5   Numero sequencial de veículo relacionado a um ...
# 6   Codigo da categoria do veiculo. Exemplos:  0 -...
# 7   Descricao do codigo da categoria do veiculo. E...
# 8   Codigo da especie do veiculo. Exemplos: 1 - bi...
# 9   Calculado a partir do valor de "cod_especie"\t...
# 10  Codigo da situacao do veiculo. Exemplos: 0 - n...
# 11  Calculado a partir do valor de "cod_situacao" ...
# 12  Codigo do tipo do socorro prestado para o acid...
# 13  Calculado a partir do valor de "tipo_socorro"\...

# %% [markdown]
# #Passo 3: Leitura e vizualização da base de dados

# %%
tabela = pd.read_csv("si-veic-2021.csv", sep=';', encoding='latin-1')


display(tabela)
# Out:
#                Nº_boletim data_hora_boletim    seq_veic   cod_categ  \
# 0      2021-014038208-001  21/03/2021 12:29           1           3
# 1      2021-014038208-001  21/03/2021 12:29           2           3
# 2      2021-014050858-001  21/03/2021 14:03           1           3
# 3      2021-014050858-001  21/03/2021 14:03           2           3
# 4      2021-014056225-001  21/03/2021 15:18           2           3
# ...                   ...               ...         ...         ...
# 20501  2021-021332901-001  03/05/2021 11:08           3           3
# 20502  2021-052672839-001  01/11/2021 11:56           1           3
# 20503  2021-057027992-001  27/11/2021 18:44           2           3
# 20504  2021-013952032-001  20/03/2021 18:43           1           3
# 20505  2021-011484135-001  06/03/2021 18:48           1           3
#
#                   descricao_categoria   cod_especie  \
# 0      PARTICULAR                                 6
# 1      PARTICULAR                                 4
# 2      PARTICULAR                                14
# 3      PARTICULAR                                 6
# 4      PARTICULAR                                 6
# ...                               ...           ...
# 20501  PARTICULAR                                 6
# 20502  PARTICULAR                                 6
# 20503  PARTICULAR                                 6
# 20504  PARTICULAR                                 6
# 20505  PARTICULAR                                 6
#
#                     descricao_especie   cod_situacao    desc_situacao  \
# 0      AUTOMOVEL                                   1  EM MOVIMENTO
# 1      MOTOCICLETA                                 1  EM MOVIMENTO
# 2      CARROCA                                     1  EM MOVIMENTO
# 3      AUTOMOVEL                                   1  EM MOVIMENTO
# 4      AUTOMOVEL                                   1  EM MOVIMENTO
# ...                               ...            ...              ...
# 20501  AUTOMOVEL                                   3  ESTACIONADO
# 20502  AUTOMOVEL                                   3  ESTACIONADO
# 20503  AUTOMOVEL                                   3  ESTACIONADO
# 20504  AUTOMOVEL                                   3  ESTACIONADO
# 20505  AUTOMOVEL                                   3  ESTACIONADO
#
#         tipo_socorro     desc_tipo_socorro
# 0                  6  NÃO SE APLICA
# 1                  5  DISPENSOU ATENDIMEN
# 2                  5  DISPENSOU ATENDIMEN
# 3                  6  NÃO SE APLICA
# 4                  6  NÃO SE APLICA
# ...              ...                   ...
# 20501              0  NÃO INFORMADO
# 20502              0  NÃO INFORMADO
# 20503              0  NÃO INFORMADO
# 20504              0  NÃO INFORMADO
# 20505              0  NÃO INFORMADO
#
# [20506 rows x 11 columns]

# %% [markdown]
# # Passo 4: Corrigir erros da base de dados
#
# > Corrigindo valores vazios
#
# > Excluindo linhas vazias
#
# > Excluindo colunas desnecessarias

# %%
# Visualizar informações antes das operações
display(tabela.info())

#Remover espaços em branco dos nomes das colunas
tabela.columns = tabela.columns.str.strip()

# Remover linhas com valores ausentes e colunas específicas
tabela = tabela.dropna()
tabela = tabela.drop(columns="Nº_boletim")

# Visualizar informações após as operações
display(tabela.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20506 entries, 0 to 20505
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0    Nº_boletim           20506 non-null  object
#  1   data_hora_boletim     20506 non-null  object
#  2     seq_veic            20506 non-null  int64
#  3    cod_categ            20506 non-null  int64
#  4    descricao_categoria  20506 non-null  object
#  5    cod_especie          20506 non-null  int64
#  6     descricao_especie   20506 non-null  object
#  7    cod_situacao         20506 non-null  int64
#  8    desc_situacao        20506 non-null  object
#  9    tipo_socorro         20506 non-null  int64
#  10   desc_tipo_socorro    20506 non-null  object
# dtypes: int64(5), object(6)
# memory usage: 1.7+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20506 entries, 0 to 20505
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   data_hora_boletim    20506 non-null  object
#  1   cod_categ            20506 non-null  int64
#  2   descricao_categoria  20506 non-null  object
#  3   cod_especie          20506 non-null  int64
#  4   descricao_especie    20506 non-null  object
#  5   cod_situacao         20506 non-null  int64
#  6   desc_situacao        20506 non-null  object
#  7   tipo_socorro         20506 non-null  int64
#  8   desc_tipo_socorro    20506 non-null  object
# dtypes: int64(4), object(5)
# memory usage: 1.4+ MB
# None

# %% [markdown]
# # Passo 5: Análise dos dados
#
# ```
#  Neste passo analizamos os dados frente a perguntas norteadoras, a quais foram elas:
#
#  ```
#
#  > Que tipo de socorro teve sua maior incidencia no ano de 2021?
#
#  > Qual foi a espécie de veículo com maior número de acidentes neste ano?
#
#  > Qual a situação do veiculo mais comum no ano analisado?
#
#  > Qual foi o horário que teve o maior número de acidentes?

# %%
tipo_socorro_mais_comum = tabela['desc_tipo_socorro'].mode().values[0]
print("\nTipo de socorro mais comum:", tipo_socorro_mais_comum)

veiculo_mais_comum = tabela['descricao_especie'].mode().values[0]
print("\nVeículo que mais ocorreu acidente:", veiculo_mais_comum)

situacao_veiculo_mais_comum = tabela['desc_situacao'].mode().values[0]
print("\nSituação em que o veículo estava:", situacao_veiculo_mais_comum)

horario_mais_ocorrido = tabela['data_hora_boletim'].str.split().str[1].str.split(':').str[0].astype(int).mode().values[0]
print("\nHorário que mais ocorreu acidente:", horario_mais_ocorrido, "horas")
# Out:
# Tipo de socorro mais comum: NÃO SE APLICA
#
# Veículo que mais ocorreu acidente: AUTOMOVEL
#
# Situação em que o veículo estava: EM MOVIMENTO
#
# Horário que mais ocorreu acidente: 17 horas

# %% [markdown]
# # Passo 6: Graficos Informativos
#
# ## Nesta sessão iremos construir graficos informativos para uma melhor elucidação das perguntas norteadoras.

# %%
# Dados para o gráfico
tipos_socorro = tabela['desc_tipo_socorro'].value_counts()
veiculos = tabela['descricao_categoria'].value_counts()
situacoes_veiculo = tabela['desc_situacao'].value_counts()

# Plotar gráficos de barras
fig, axs = plt.subplots(2, 2, figsize=(15, 10))

axs[0, 0].bar(tipos_socorro.index, tipos_socorro.values, color='skyblue')
axs[0, 0].set_title('Tipos de Socorro')
axs[0, 0].set_ylabel('Quantidade')
axs[0, 0].tick_params(axis='x', rotation=45)  # Rotaciona os rótulos do eixo x

axs[0, 1].bar(veiculos.index, veiculos.values, color='salmon')
axs[0, 1].set_title('Veículos Envolvidos')
axs[0, 1].set_ylabel('Quantidade')
axs[0, 1].tick_params(axis='x', rotation=45)  # Rotaciona os rótulos do eixo x

axs[1, 0].bar(situacoes_veiculo.index, situacoes_veiculo.values, color='lightgreen')
axs[1, 0].set_title('Situação dos Veículos')
axs[1, 0].set_ylabel('Quantidade')
axs[1, 0].tick_params(axis='x', rotation=45)  # Rotaciona os rótulos do eixo x

# Remover o último subplot
fig.delaxes(axs[1,1])

plt.tight_layout()
plt.show()

# %%
especie_count = tabela['descricao_especie'].value_counts()

especie_perc = 100. * especie_count / especie_count.sum()

especie_filtrado = especie_perc[especie_perc >=1.7  ]

# Gerar o gráfico de pizza
fig, ax = plt.subplots(figsize=(10, 10))
wedges, texts, autotexts = ax.pie(especie_filtrado, autopct='%1.1f%%', startangle=140)

ax.legend(wedges, especie_filtrado.index,
          title="descricao_especie",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(texts, rotation_mode="anchor", ha="right")

plt.title('Distribuição de descricao_especie (acima de 1.7%)')
plt.show()

# %% [markdown]
# # Discussão:
#
# ## Com a analise dos dados supracitados, podemos observar que meios de locomoção da especie Automovel, tem a maior parcela no numero de acidentes com vitimas no ano de 2021, onde em sua maioria os acidentes ocorreram com automiveis particulares e que estavam em movimento.Seguido por motocicletas onde se somados (automoveis e motocicletas) detem mais de 80% do numero de acidentes com vitima ocorridos no ano de 2021 na cidade de Belo horizonte.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
